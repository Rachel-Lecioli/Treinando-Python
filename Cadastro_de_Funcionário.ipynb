# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachel-Lecioli/Treinando-Python/blob/main/Cadastro_de_Funcion%C3%A1rio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
soma_idade = 0
média_idade = 0
homem_mais_velho = 0
nome_mais_velho = ''
mulheres_20 = 0
for pessoa in range(1, 3):
    print(f'---- {pessoa}º PESSOA ----')
    nome = str(input('Nome: ')).strip()
    idade = int(input('Idade: '))
    sexo = str(input('Sexo [M/F]: ')).strip().upper()
    soma_idade = soma_idade + idade
    if pessoa == 1 and sexo == 'M':
        homem_mais_velho = idade
        nome_mais_velho = nome
    if sexo == 'M' and idade > homem_mais_velho:
        homem_mais_velho = idade
        nome_mais_velho = nome
    if sexo == 'F' and idade < 20:
        mulheres_20 = mulheres_20 + 1
média_idade = soma_idade / 4
print(f'A média de idade do grupo é de {média_idade} anos.')
print(f'O homem mais velho tem {homem_mais_velho} anos e se chama {nome_mais_velho}.')
print(f'Ao todo são {mulheres_20} mulheres com menos de 20 anos.')
# Out:
# ---- 1º PESSOA ----
# Nome: leo
# Idade: 25
# Sexo [M/F]: m
# ---- 2º PESSOA ----
# Nome: rachel
# Idade: 30
# Sexo [M/F]: f
# A média de idade do grupo é de 13.75 anos.
# O homem mais velho tem 25 anos e se chama leo.
# Ao todo são 0 mulheres com menos de 20 anos.

# %%
from datetime import datetime
pessoa = {}
pessoa['nome'] = str(input('Nome: '))
nascimento = int(input('Ano de Nascimento: '))
pessoa['idade'] = datetime.now().year - nascimento
pessoa['carteira'] = int(input('Carteira de Trabalho (0 - não tem): '))
if pessoa['carteira'] != 0:
    pessoa['contratação'] = int(input('Ano de Contratação: '))
    pessoa['salário'] = float(input('Salário: R$ '))
    pessoa['aposentadoria'] = pessoa['idade'] + ((pessoa['contratação'] + 35) - datetime.now().year)
print('-' * 30)
for k, v in pessoa.items():
    print(f'- {k} tem o valor {v}')
# Out:
# Nome: rachel
# Ano de Nascimento: 2001
# Carteira de Trabalho (0 - não tem): 0
# ------------------------------
# - nome tem o valor rachel
# - idade tem o valor 25
# - carteira tem o valor 0
